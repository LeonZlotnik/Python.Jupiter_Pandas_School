# %%
import pandas as pd
import numpy as np

school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data_complete.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
                                    
schools_total = school_data_complete.groupby("school_name").sum()
schools_total

school_values = schools_total['School ID'].reset_index()
school_values

schools_value = school_values['School ID'].count()
schools_value
# Out:
# 15

# %%
student_total = school_data_complete.groupby("student_name").sum()
student_total

student_values = student_total['Student ID'].reset_index()
student_values

student_value = student_values['Student ID'].count()
student_value
# Out:
# 32715

# %%
budget_total = school_data_complete.agg({'budget':['sum']})
budget_total
# Out:
#           budget
# sum  82932329558

# %%
math_total = school_data_complete.agg({'math_score':['sum','mean']})
math_total
# Out:
#         math_score
# sum   3.093857e+06
# mean  7.898537e+01

# %%
reading_total = school_data_complete.agg({'reading_score':['sum','mean']})
reading_total
# Out:
#       reading_score
# sum    3.207155e+06
# mean   8.187784e+01

# %%
average = school_data_complete.set_index('Student ID')
average

average_drop = average.drop(columns=['student_name', 'gender', 'grade', 'school_name','School ID', 'type', 'size', 'budget'])
average_drop

#average_pass = average_reading.reset_index()
#average_pass

#failed_reading = average_pass.drop(index=5,inplace=False)
#failed_reading

#average_pass_reading = failed_reading.agg({'reading_score'['mean']})
#average_pass_reading
# Out:
#             reading_score  math_score
# Student ID
# 0                      66          79
# 1                      94          61
# 2                      90          60
# 3                      67          58
# 4                      97          84
# 5                      94          94
# 6                      82          80
# 7                      96          69
# 8                      95          87
# 9                      96          84
# 10                     90          70
# 11                     78          77
# 12                     64          79
# 13                     71          79
# 14                     85          67
# 15                     94          88
# 16                     88          55
# 17                     74          75
# 18                     64          69
# 19                     89          80
# 20                     91          89
# 21                     90          77
# 22                     99          84
# ...

# %%
student_df = school_data_complete.groupby('student_name').sum()
student_df

scores_reading = student_df['reading_score']>=70
scores_reading

pass_reading = scores_reading.mean()
pass_reading
# Out:
# 0.8759284731774415

# %%
student_df = school_data_complete.groupby('student_name').sum()
student_df

scores_math = student_df['math_score']>=70
scores_math

pass_math = scores_math.mean()
pass_math
# Out:
# 0.7832798410515054

# %%
overall_pass = (pass_math + pass_reading)/2
overall_pass
# Out:
# 0.8296041571144734

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
Schools_total = school_data.groupby('budget').sum()
Schools_total
# Out:
#          School ID  size
# budget
# 248087           8   427
# 585858           9   962
# 917500           4  1468
# 1043130         14  1635
# 1049400         10  1800
# 1056600          2  1761
# 1081356          6  1858
# 1319574          5  2283
# 1763916         13  2739
# 1884411          1  2949
# 1910635          0  2917
# 2547363         11  3999
# 3022020          3  4635
# 3094650         12  4761
# 3124928          7  4976

# %%
Budget_per_school = Schools_total.drop(columns=['size','School ID'])
Budget_per_school
# Out:
# Empty DataFrame
# Columns: []
# Index: [248087, 585858, 917500, 1043130, 1049400, 1056600, 1081356, 1319574, 1763916, 1884411, 1910635, 2547363, 3022020, 3094650, 3124928]

# %%
merge_school_total = Budget_per_school.merge(school_data, on=["budget"])
merge_school_total

budget_per_student = merge_school_total.groupby('school_name').sum()
budget_per_student
# Out:
#                         budget  School ID  size
# school_name
# Bailey High School     3124928          7  4976
# Cabrera High School    1081356          6  1858
# Figueroa High School   1884411          1  2949
# Ford High School       1763916         13  2739
# Griffin High School     917500          4  1468
# Hernandez High School  3022020          3  4635
# Holden High School      248087          8   427
# Huang High School      1910635          0  2917
# Johnson High School    3094650         12  4761
# Pena High School        585858          9   962
# Rodriguez High School  2547363         11  3999
# Shelton High School    1056600          2  1761
# Thomas High School     1043130         14  1635
# Wilson High School     1319574          5  2283
# Wright High School     1049400         10  1800

# %%
budget_per_student['budget per student'] = budget_per_student['budget']/budget_per_student['size']
budget_per_student
# Out:
#                         budget  School ID  size  budget_per_student  \
# school_name
# Bailey High School     3124928          7  4976               628.0
# Cabrera High School    1081356          6  1858               582.0
# Figueroa High School   1884411          1  2949               639.0
# Ford High School       1763916         13  2739               644.0
# Griffin High School     917500          4  1468               625.0
# Hernandez High School  3022020          3  4635               652.0
# Holden High School      248087          8   427               581.0
# Huang High School      1910635          0  2917               655.0
# Johnson High School    3094650         12  4761               650.0
# Pena High School        585858          9   962               609.0
# Rodriguez High School  2547363         11  3999               637.0
# Shelton High School    1056600          2  1761               600.0
# Thomas High School     1043130         14  1635               638.0
# ...

# %%
raname = budget_per_student.rename(columns={'budget':'total budget'})
raname
# Out:
#                        total budget  School ID  size  budget_per_student  \
# school_name
# Bailey High School          3124928          7  4976               628.0
# Cabrera High School         1081356          6  1858               582.0
# Figueroa High School        1884411          1  2949               639.0
# Ford High School            1763916         13  2739               644.0
# Griffin High School          917500          4  1468               625.0
# Hernandez High School       3022020          3  4635               652.0
# Holden High School           248087          8   427               581.0
# Huang High School           1910635          0  2917               655.0
# Johnson High School         3094650         12  4761               650.0
# Pena High School             585858          9   962               609.0
# Rodriguez High School       2547363         11  3999               637.0
# Shelton High School         1056600          2  1761               600.0
# ...

# %%
final_school_table = raname.drop(columns={'budget_per_student','size','School ID'})
final_school_table
# Out:
#                        total budget  budget per student
# school_name
# Bailey High School          3124928               628.0
# Cabrera High School         1081356               582.0
# Figueroa High School        1884411               639.0
# Ford High School            1763916               644.0
# Griffin High School          917500               625.0
# Hernandez High School       3022020               652.0
# Holden High School           248087               581.0
# Huang High School           1910635               655.0
# Johnson High School         3094650               650.0
# Pena High School             585858               609.0
# Rodriguez High School       2547363               637.0
# Shelton High School         1056600               600.0
# Thomas High School          1043130               638.0
# Wilson High School          1319574               578.0
# Wright High School          1049400               583.0
